# %%
# !nvidia-smi
# Out:
# Sun Apr  7 15:00:10 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.116.04   Driver Version: 525.116.04   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A4000    Off  | 00000000:00:05.0 Off |                  Off |
# | 41%   34C    P8    13W / 140W |      1MiB / 16376MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
# Out:
# 2024-04-13 17:22:45.316356: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def resnet_block(input_layer, filters, kernel_size, strides=(1, 1), activation='relu'):
    x = layers.Conv2D(filters, kernel_size, strides=strides, padding='same')(input_layer)
    x = layers.BatchNormalization()(x)
    if activation:
        x = layers.Activation(activation)(x)
    return x

def build_resnet(input_shape, num_classes, type='resnet18'):
    inputs = tf.keras.Input(shape=input_shape)

    x = layers.Conv2D(64, 7, strides=2, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x)

    if type == 'resnet18':
        num_blocks_list = [2, 2, 2, 2]
        filters_list = [64, 128, 256, 512]
    elif type == 'resnet34':
        num_blocks_list = [3, 4, 6, 3]
        filters_list = [64, 128, 256, 512]
    else:
        raise ValueError('ResNet type not supported')

    for i, num_blocks in enumerate(num_blocks_list):
        for j in range(num_blocks):
            strides = (1, 1)
            if i > 0 and j == 0:
                strides = (2, 2)
            if j == 0:
                shortcut = layers.Conv2D(filters_list[i], 1, strides=strides, padding='same')(x)
                shortcut = layers.BatchNormalization()(shortcut)
                x = resnet_block(x, filters_list[i], 3, strides=strides)
                x = layers.add([x, shortcut])
            else:
                x = resnet_block(x, filters_list[i], 3)

    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# %%
# Load CIFAR-10 data
cifar10 = tf.keras.datasets.cifar10.load_data()
(x_train, y_train), (x_test, y_test) = cifar10
input_shape = x_train.shape[1:]
num_classes = 10
# Preprocess data
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
# Build and compile the model
model = build_resnet(input_shape, num_classes, type='resnet34')
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# <keras.engine.functional.Functional object at 0x7f49702a1f70>

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 64)   9472        ['input_2[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_21[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_17[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 8, 8, 64)     36928       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 8, 8, 64)    256         ['conv2d_23[0][0]']
#  ormalization)
#
#  conv2d_22 (Conv2D)             (None, 8, 8, 64)     4160        ['max_pooling2d_1[0][0]']
#
#  activation_18 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_23[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 8, 8, 64)    256         ['conv2d_22[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 8, 8, 64)     0           ['activation_18[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 8, 8, 64)     36928       ['add_4[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 64)    256         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_19[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 8, 8, 64)    256         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 4, 4, 128)    73856       ['activation_20[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 4, 4, 128)   512         ['conv2d_27[0][0]']
#  ormalization)
#
#  conv2d_26 (Conv2D)             (None, 4, 4, 128)    8320        ['activation_20[0][0]']
#
#  activation_21 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_27[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 4, 4, 128)   512         ['conv2d_26[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 4, 4, 128)    0           ['activation_21[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 4, 4, 128)    147584      ['add_5[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 4, 4, 128)   512         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_22[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 4, 4, 128)   512         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_23[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 4, 4, 128)   512         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 2, 2, 256)    295168      ['activation_24[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_32[0][0]']
#  ormalization)
#
#  conv2d_31 (Conv2D)             (None, 2, 2, 256)    33024       ['activation_24[0][0]']
#
#  activation_25 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_32[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_31[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 2, 2, 256)    0           ['activation_25[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 2, 2, 256)    590080      ['add_6[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_26[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_27[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_28[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_29[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 1, 1, 512)    1180160     ['activation_30[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_39[0][0]']
#  ormalization)
#
#  conv2d_38 (Conv2D)             (None, 1, 1, 512)    131584      ['activation_30[0][0]']
#
#  activation_31 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_39[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_38[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 1, 1, 512)    0           ['activation_31[0][0]',
#                                                                   'batch_normalization_38[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 1, 1, 512)    2359808     ['add_7[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_32[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_41[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 512)         0           ['activation_33[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 10)           5130        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 9,983,626
# Trainable params: 9,974,026
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
# Train the model
model.fit(x_train, y_train, batch_size=64, epochs=25, validation_data=(x_test, y_test))
# Out:
# Epoch 1/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.3306 - accuracy: 0.8875 - val_loss: 1.2310 - val_accuracy: 0.6807
# Epoch 2/25
# 782/782 [==============================] - 9s 12ms/step - loss: 0.2819 - accuracy: 0.9052 - val_loss: 0.9954 - val_accuracy: 0.7308
# Epoch 3/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.2492 - accuracy: 0.9170 - val_loss: 1.2275 - val_accuracy: 0.7025
# Epoch 4/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.2123 - accuracy: 0.9282 - val_loss: 1.1840 - val_accuracy: 0.7111
# Epoch 5/25
# 782/782 [==============================] - 10s 12ms/step - loss: 0.1834 - accuracy: 0.9379 - val_loss: 1.0506 - val_accuracy: 0.7409
# Epoch 6/25
# 782/782 [==============================] - 10s 12ms/step - loss: 0.1620 - accuracy: 0.9459 - val_loss: 1.0827 - val_accuracy: 0.7490
# Epoch 7/25
# 782/782 [==============================] - 9s 12ms/step - loss: 0.1477 - accuracy: 0.9502 - val_loss: 1.1693 - val_accuracy: 0.7445
# Epoch 8/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.1396 - accuracy: 0.9543 - val_loss: 1.4315 - val_accuracy: 0.7027
# Epoch 9/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.1254 - accuracy: 0.9588 - val_loss: 1.1637 - val_accuracy: 0.7394
# Epoch 10/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.1125 - accuracy: 0.9628 - val_loss: 1.1513 - val_accuracy: 0.7415
# Epoch 11/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.1058 - accuracy: 0.9641 - val_loss: 1.5853 - val_accuracy: 0.6897
# Epoch 12/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.1042 - accuracy: 0.9655 - val_loss: 1.5000 - val_accuracy: 0.7211
# Epoch 13/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.0952 - accuracy: 0.9682 - val_loss: 1.1590 - val_accuracy: 0.7529
# Epoch 14/25
# 782/782 [==============================] - 10s 12ms/step - loss: 0.0912 - accuracy: 0.9706 - val_loss: 1.1507 - val_accuracy: 0.7511
# Epoch 15/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.0838 - accuracy: 0.9729 - val_loss: 1.4253 - val_accuracy: 0.7346
# Epoch 16/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.0773 - accuracy: 0.9737 - val_loss: 1.4898 - val_accuracy: 0.7071
# Epoch 17/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.0848 - accuracy: 0.9720 - val_loss: 1.2233 - val_accuracy: 0.7520
# Epoch 18/25
# 782/782 [==============================] - 10s 12ms/step - loss: 0.0748 - accuracy: 0.9756 - val_loss: 1.3606 - val_accuracy: 0.7300
# Epoch 19/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.0716 - accuracy: 0.9768 - val_loss: 1.1779 - val_accuracy: 0.7539
# Epoch 20/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.0669 - accuracy: 0.9781 - val_loss: 1.3565 - val_accuracy: 0.7412
# Epoch 21/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.0653 - accuracy: 0.9784 - val_loss: 1.3592 - val_accuracy: 0.7461
# Epoch 22/25
# 782/782 [==============================] - 11s 14ms/step - loss: 0.0609 - accuracy: 0.9808 - val_loss: 1.4635 - val_accuracy: 0.7252
# Epoch 23/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.0657 - accuracy: 0.9787 - val_loss: 1.3830 - val_accuracy: 0.7505
# Epoch 24/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.0535 - accuracy: 0.9823 - val_loss: 1.3682 - val_accuracy: 0.7446
# Epoch 25/25
# 782/782 [==============================] - 10s 13ms/step - loss: 0.0571 - accuracy: 0.9815 - val_loss: 1.3180 - val_accuracy: 0.7475

# %%
import numpy as np
import matplotlib.pyplot as plt

# CIFAR-10 class names
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)

# Predict on test data
predictions = model.predict(x_test)
# Show some random predictions
num_samples_to_show = 5
random_indices = np.random.choice(range(len(x_test)), num_samples_to_show, replace=False)

plt.figure(figsize=(15, 3))

for i, idx in enumerate(random_indices):
    predicted_class_idx = np.argmax(predictions[idx])
    expected_class_idx = y_test[idx][0]
    
    predicted_class_name = class_names[predicted_class_idx]
    expected_class_name = class_names[expected_class_idx]
    
    plt.subplot(1, num_samples_to_show, i+1)
    plt.imshow(x_test[idx])
    plt.title(f"Predicted: {predicted_class_name}\nExpected: {expected_class_name}")
    plt.axis('off')

plt.show()
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 1.3180 - accuracy: 0.7475
# Test Loss: 1.3180073499679565
# Test Accuracy: 0.7475000023841858
# 313/313 [==============================] - 1s 3ms/step
